# %% [markdown]
# # 🧌 RuneLite Goblin Bot
#
# This is a **computer vision bot** that detects and attacks goblins in RuneLite using **YOLOv8** and **Win32 screen capture**.
# The bot tracks goblins in real time, allowing you to manually attack by pressing **'E'**.
#
# ## **⚡ Features**
# ✅ **Real-time goblin tracking** using YOLO
# ✅ **Press 'E' to attack**, 'Q' to quit
# ✅ **Does NOT require the game window to be active**
# ✅ **Works without GPU acceleration (CPU-only)**
#
# ---
#
# ## **🚀 Setup & Installation**
# ### **1️⃣ Install Dependencies**
# Make sure you have Python installed, then run:
# ```bash
# pip install -r requirements.txt

# %%
import torch
import numpy as np
import mss
import cv2
import time
import pyautogui
import pygetwindow as gw
from PIL import Image
from ultralytics import YOLO

# %% [markdown]
# ## 📌 get_game_region_auto() – Auto-Detect RuneLite Window
# This function automatically detects the RuneLite window and extracts its position and size.
# It removes the need for manual mouse placement, making setup faster and more efficient.
#
# ### 🛠️ How It Works
# ##### 1️⃣ Finds RuneLite's window using getWindowsWithTitle("RuneLite")
# ##### 2️⃣ Extracts window position & size (top, left, width, height)
# ##### 3️⃣ Returns the game region as a dictionary
# ##### 4️⃣ Prints confirmation when the window is found

# %%
def get_game_region_auto():
    # Find the RuneLite window
    windows = gw.getWindowsWithTitle("RuneLite")

    if not windows:
        print("❌ RuneLite window not found! Make sure it's open.")
        return None

    runelite_window = windows[0]  # Assuming the first match is the correct window

    # Extract window coordinates
    game_region = {
        "top": runelite_window.top,
        "left": runelite_window.left,
        "width": runelite_window.width,
        "height": runelite_window.height
    }

    print("\n🎯 **Game Window Detected Automatically!**")
    print(f"📍 **Game Region:** Top={game_region['top']}, Left={game_region['left']}, Width={game_region['width']}, Height={game_region['height']}\n")

    return game_region

# ✅ Automatically detect RuneLite window
game_region = get_game_region_auto()
# Out:
# 🎯 **Game Window Detected Automatically!**
# 📍 **Game Region:** Top=101, Left=947, Width=836, Height=582

# %% [markdown]
# # 🧌
# ####  📌 1. capture_runeLite_window(window_name)
# ##### Captures the RuneLite game window using the Win32 API.
# ##### Returns a screenshot as a NumPy array.
#
# #### 📌 2. delayed_bot_and_tracking(model)
# ##### Opens an OpenCV window for real-time detection.
# ##### Captures RuneLite’s window every frame.
# ##### Runs YOLO object detection to find goblins.
# ##### Tracks the closest goblin to the center of the screen.

# %%
import time
import cv2
import numpy as np
import pyautogui
import keyboard  
import win32gui, win32ui, win32con
from ultralytics import YOLO
from collections import deque

# **RuneLite Window Title**
window_name = "RuneLite - SavignonRed"

# **Goblin Class ID = 2
TARGET_CLASSES = {2}

def capture_runeLite_window(window_name):
    """Captures the RuneLite window as an image using Win32 API."""
    hwnd = win32gui.FindWindow(None, window_name)
    if not hwnd:
        print("❌ Error: RuneLite window not found.")
        return None, None

    left, top, right, bottom = win32gui.GetWindowRect(hwnd)
    width, height = right - left, bottom - top

    hdc = win32gui.GetWindowDC(hwnd)
    dc_obj = win32ui.CreateDCFromHandle(hdc)
    mem_dc = dc_obj.CreateCompatibleDC()
    bmp = win32ui.CreateBitmap()
    bmp.CreateCompatibleBitmap(dc_obj, width, height)
    mem_dc.SelectObject(bmp)
    mem_dc.BitBlt((0, 0), (width, height), dc_obj, (0, 0), win32con.SRCCOPY)

    bmp_info = bmp.GetInfo()
    img = np.frombuffer(bmp.GetBitmapBits(True), dtype=np.uint8)
    img.shape = (bmp_info['bmHeight'], bmp_info['bmWidth'], 4)

    win32gui.DeleteObject(bmp.GetHandle())
    mem_dc.DeleteDC()
    dc_obj.DeleteDC()
    win32gui.ReleaseDC(hwnd, hdc)

    return cv2.cvtColor(img, cv2.COLOR_BGRA2RGB), (left, top, width, height)

def delayed_bot_and_tracking(model):
    """Tracks goblins but only clicks when 'E' is pressed."""
    
    print("✅ Tracking started. Press 'E' to attack. Press 'Q' to exit.")

    cv2.namedWindow("RuneLite - Goblin Tracking", cv2.WINDOW_NORMAL)  # Create OpenCV window
    track_history = deque(maxlen=5)
    last_goblin_position = None  # Stores last detected goblin position

    while True:
        frame, game_region = capture_runeLite_window(window_name)
        if frame is None:
            print("❌ Error: Could not capture RuneLite window.")
            break

        pil_img = Image.fromarray(frame)
        results = model(pil_img, imgsz=320)  # Faster inference (no CUDA)

        if not results[0].boxes or len(results[0].boxes) == 0:
            print("⚠️ No goblins detected.")
            last_goblin_position = None
            continue

        boxes = results[0].boxes.xyxy.cpu().numpy()
        classes = results[0].boxes.cls.cpu().numpy()
        confidences = results[0].boxes.conf.cpu().numpy()

        img_with_boxes = np.array(results[0].plot())

        # **Fix OpenCV Window Display Issues**
        cv2.imshow("RuneLite - Goblin Tracking", img_with_boxes)
        if cv2.getWindowProperty("RuneLite - Goblin Tracking", cv2.WND_PROP_VISIBLE) < 1:
            print("❌ OpenCV window closed. Exiting bot.")
            break

        cv2.waitKey(1)  # Keep OpenCV window responsive

        # **Global Key Listener (E = Attack, Q = Quit)**
        if keyboard.is_pressed('q'):
            print("❌ Stopping bot & tracking.")
            break

        # **Find the best goblin to attack (closest to screen center)**
        best_box, best_center = None, None
        best_distance = float("inf")

        screen_center_x = game_region[2] // 2
        screen_center_y = game_region[3] // 2

        for i, box in enumerate(boxes):
            if classes[i] not in TARGET_CLASSES or confidences[i] < 0.3:
                continue  # Only select goblins with confidence > 0.3

            x1, y1, x2, y2 = map(int, box)
            box_center_x = (x1 + x2) // 2
            box_center_y = (y1 + y2) // 2

            distance = ((box_center_x - screen_center_x) ** 2 + (box_center_y - screen_center_y) ** 2) ** 0.5

            if distance < best_distance:
                best_distance = distance
                best_box = box
                best_center = (box_center_x, box_center_y)

        if best_box is not None:
            # Convert to screen coordinates
            screen_x = game_region[0] + best_center[0]
            screen_y = game_region[1] + best_center[1]

            last_goblin_position = (screen_x, screen_y)  # Store last detected goblin

        # **Click only when 'E' is pressed (from ANY window)**
        if keyboard.is_pressed('e') and last_goblin_position:
            print(f"🎯 Attacking goblin at ({last_goblin_position[0]}, {last_goblin_position[1]})...")
            pyautogui.moveTo(last_goblin_position[0], last_goblin_position[1], duration=np.random.uniform(0.1, 0.2))
            pyautogui.click()
            print("✅ Clicked on goblin.")

    cv2.destroyAllWindows()
    print("✅ Bot & tracking loop exited safely.")

# Load YOLOv11 model (No CUDA)
model = YOLO(r"C:/Users/nicol/Computer Vision Group/best.pt")  

# Run bot
delayed_bot_and_tracking(model)
# Out:
# ✅ Tracking started. Press 'E' to attack. Press 'Q' to exit.
#
# 0: 224x320 5 goblins, 54.6ms
# Speed: 2.6ms preprocess, 54.6ms inference, 0.8ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 4 goblins, 53.9ms
# Speed: 1.1ms preprocess, 53.9ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 4 goblins, 44.1ms
# Speed: 1.0ms preprocess, 44.1ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 5 goblins, 49.5ms
# Speed: 1.0ms preprocess, 49.5ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 5 goblins, 51.3ms
# Speed: 2.5ms preprocess, 51.3ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 5 goblins, 43.7ms
# Speed: 1.1ms preprocess, 43.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 5 goblins, 43.5ms
# Speed: 0.9ms preprocess, 43.5ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 5 goblins, 43.7ms
# Speed: 0.8ms preprocess, 43.7ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 4 goblins, 43.7ms
# Speed: 0.9ms preprocess, 43.7ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 4 goblins, 52.7ms
# Speed: 1.3ms preprocess, 52.7ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 4 goblins, 48.7ms
# Speed: 1.2ms preprocess, 48.7ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 4 goblins, 40.9ms
# Speed: 0.9ms preprocess, 40.9ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 1 goblin, 54.1ms
# Speed: 1.5ms preprocess, 54.1ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 1 goblin, 50.1ms
# Speed: 1.2ms preprocess, 50.1ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 46.7ms
# Speed: 0.8ms preprocess, 46.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 41.1ms
# Speed: 0.9ms preprocess, 41.1ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 2 goblins, 41.9ms
# Speed: 1.1ms preprocess, 41.9ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 2 goblins, 57.2ms
# Speed: 1.0ms preprocess, 57.2ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 2 goblins, 53.5ms
# Speed: 1.0ms preprocess, 53.5ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 2 goblins, 61.2ms
# Speed: 0.9ms preprocess, 61.2ms inference, 0.9ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 65.2ms
# Speed: 0.9ms preprocess, 65.2ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 40.6ms
# Speed: 0.8ms preprocess, 40.6ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 4 goblins, 42.4ms
# Speed: 1.1ms preprocess, 42.4ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 4 goblins, 43.2ms
# Speed: 0.9ms preprocess, 43.2ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 58.7ms
# Speed: 1.2ms preprocess, 58.7ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 43.1ms
# Speed: 1.0ms preprocess, 43.1ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 4 goblins, 43.6ms
# Speed: 1.0ms preprocess, 43.6ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 4 goblins, 40.0ms
# Speed: 0.9ms preprocess, 40.0ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 6 goblins, 42.7ms
# Speed: 0.8ms preprocess, 42.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 6 goblins, 41.8ms
# Speed: 1.0ms preprocess, 41.8ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 5 goblins, 35.6ms
# Speed: 0.9ms preprocess, 35.6ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 5 goblins, 37.7ms
# Speed: 0.9ms preprocess, 37.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 4 goblins, 36.8ms
# Speed: 0.8ms preprocess, 36.8ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 4 goblins, 37.8ms
# Speed: 1.4ms preprocess, 37.8ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 4 goblins, 37.0ms
# Speed: 0.9ms preprocess, 37.0ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 63.4ms
# Speed: 1.3ms preprocess, 63.4ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 49.7ms
# Speed: 1.0ms preprocess, 49.7ms inference, 0.9ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 4 goblins, 41.7ms
# Speed: 1.0ms preprocess, 41.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 4 goblins, 52.0ms
# Speed: 1.0ms preprocess, 52.0ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 38.7ms
# Speed: 1.0ms preprocess, 38.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 4 goblins, 41.1ms
# Speed: 0.9ms preprocess, 41.1ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 40.1ms
# Speed: 0.8ms preprocess, 40.1ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 4 goblins, 41.7ms
# Speed: 0.8ms preprocess, 41.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 6 goblins, 51.8ms
# Speed: 1.5ms preprocess, 51.8ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 5 goblins, 48.9ms
# Speed: 1.2ms preprocess, 48.9ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 5 goblins, 39.7ms
# Speed: 0.8ms preprocess, 39.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 6 goblins, 43.3ms
# Speed: 1.0ms preprocess, 43.3ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 7 goblins, 44.5ms
# Speed: 0.9ms preprocess, 44.5ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 6 goblins, 39.1ms
# Speed: 0.8ms preprocess, 39.1ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 6 goblins, 40.3ms
# Speed: 0.7ms preprocess, 40.3ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 7 goblins, 42.0ms
# Speed: 0.8ms preprocess, 42.0ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 5 goblins, 40.4ms
# Speed: 0.8ms preprocess, 40.4ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 4 goblins, 46.3ms
# Speed: 1.0ms preprocess, 46.3ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 41.2ms
# Speed: 1.1ms preprocess, 41.2ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 38.0ms
# Speed: 0.8ms preprocess, 38.0ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 45.9ms
# Speed: 0.9ms preprocess, 45.9ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 50.4ms
# Speed: 1.0ms preprocess, 50.4ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 5 goblins, 45.8ms
# Speed: 0.9ms preprocess, 45.8ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 5 goblins, 43.5ms
# Speed: 0.9ms preprocess, 43.5ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 7 goblins, 41.9ms
# Speed: 1.0ms preprocess, 41.9ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 4 goblins, 44.3ms
# Speed: 1.0ms preprocess, 44.3ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 4 goblins, 39.7ms
# Speed: 1.0ms preprocess, 39.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 4 goblins, 78.7ms
# Speed: 1.0ms preprocess, 78.7ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 4 goblins, 44.1ms
# Speed: 0.9ms preprocess, 44.1ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 43.8ms
# Speed: 1.0ms preprocess, 43.8ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 2 goblins, 37.4ms
# Speed: 1.3ms preprocess, 37.4ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 2 goblins, 39.2ms
# Speed: 0.7ms preprocess, 39.2ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 41.8ms
# Speed: 0.8ms preprocess, 41.8ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 1 goblin, 36.3ms
# Speed: 0.9ms preprocess, 36.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 1 goblin, 38.7ms
# Speed: 1.0ms preprocess, 38.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 34.0ms
# Speed: 0.8ms preprocess, 34.0ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 36.7ms
# Speed: 0.8ms preprocess, 36.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 36.2ms
# Speed: 0.8ms preprocess, 36.2ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 44.7ms
# Speed: 1.1ms preprocess, 44.7ms inference, 0.8ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 2 goblins, 37.4ms
# Speed: 0.8ms preprocess, 37.4ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 37.9ms
# Speed: 0.8ms preprocess, 37.9ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 41.8ms
# Speed: 1.0ms preprocess, 41.8ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 2 goblins, 41.8ms
# Speed: 0.8ms preprocess, 41.8ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 2 goblins, 42.9ms
# Speed: 0.9ms preprocess, 42.9ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 38.3ms
# Speed: 0.8ms preprocess, 38.3ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 44.1ms
# Speed: 0.9ms preprocess, 44.1ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 2 goblins, 39.6ms
# Speed: 0.8ms preprocess, 39.6ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 2 goblins, 39.4ms
# Speed: 0.7ms preprocess, 39.4ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 37.4ms
# Speed: 0.8ms preprocess, 37.4ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 39.4ms
# Speed: 0.8ms preprocess, 39.4ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 320)
# 🎯 Attacking goblin at (368, 193)...
# ✅ Clicked on goblin.
#
# 0: 224x320 (no detections), 84.4ms
# Speed: 2.4ms preprocess, 84.4ms inference, 0.3ms postprocess per image at shape (1, 3, 224, 320)
# ⚠️ No goblins detected.
#
# 0: 224x320 (no detections), 48.4ms
# Speed: 0.9ms preprocess, 48.4ms inference, 0.3ms postprocess per image at shape (1, 3, 224, 320)
# ⚠️ No goblins detected.
#
# 0: 224x320 (no detections), 72.5ms
# Speed: 0.8ms preprocess, 72.5ms inference, 0.3ms postprocess per image at shape (1, 3, 224, 320)
# ⚠️ No goblins detected.
#
# 0: 224x320 1 goblin, 45.8ms
# Speed: 1.0ms preprocess, 45.8ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 1 goblin, 45.4ms
# Speed: 1.0ms preprocess, 45.4ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 1 goblin, 45.7ms
# Speed: 1.0ms preprocess, 45.7ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 1 goblin, 42.5ms
# Speed: 1.5ms preprocess, 42.5ms inference, 0.4ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 44.2ms
# Speed: 1.6ms preprocess, 44.2ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 (no detections), 42.3ms
# Speed: 0.9ms preprocess, 42.3ms inference, 0.2ms postprocess per image at shape (1, 3, 224, 320)
# ⚠️ No goblins detected.
#
# 0: 224x320 (no detections), 44.9ms
# Speed: 0.8ms preprocess, 44.9ms inference, 0.3ms postprocess per image at shape (1, 3, 224, 320)
# ⚠️ No goblins detected.
#
# 0: 224x320 (no detections), 41.8ms
# Speed: 0.8ms preprocess, 41.8ms inference, 0.3ms postprocess per image at shape (1, 3, 224, 320)
# ⚠️ No goblins detected.
#
# 0: 224x320 1 goblin, 41.3ms
# Speed: 0.7ms preprocess, 41.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 (no detections), 38.3ms
# Speed: 1.0ms preprocess, 38.3ms inference, 0.3ms postprocess per image at shape (1, 3, 224, 320)
# ⚠️ No goblins detected.
#
# 0: 224x320 2 goblins, 36.1ms
# Speed: 0.8ms preprocess, 36.1ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 2 goblins, 40.1ms
# Speed: 0.9ms preprocess, 40.1ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 2 goblins, 38.1ms
# Speed: 0.9ms preprocess, 38.1ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 2 goblins, 36.7ms
# Speed: 0.8ms preprocess, 36.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 2 goblins, 41.0ms
# Speed: 1.0ms preprocess, 41.0ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 2 goblins, 39.3ms
# Speed: 0.7ms preprocess, 39.3ms inference, 0.8ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 (no detections), 39.2ms
# Speed: 0.8ms preprocess, 39.2ms inference, 0.3ms postprocess per image at shape (1, 3, 224, 320)
# ⚠️ No goblins detected.
#
# 0: 224x320 (no detections), 36.4ms
# Speed: 0.7ms preprocess, 36.4ms inference, 0.3ms postprocess per image at shape (1, 3, 224, 320)
# ⚠️ No goblins detected.
#
# 0: 224x320 4 goblins, 38.5ms
# Speed: 0.7ms preprocess, 38.5ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 4 goblins, 47.7ms
# Speed: 0.8ms preprocess, 47.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 4 goblins, 46.7ms
# Speed: 0.8ms preprocess, 46.7ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 2 goblins, 39.3ms
# Speed: 0.8ms preprocess, 39.3ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 41.5ms
# Speed: 0.8ms preprocess, 41.5ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
# 🎯 Attacking goblin at (393, 340)...
# ✅ Clicked on goblin.
#
# 0: 224x320 1 goblin, 48.2ms
# Speed: 1.4ms preprocess, 48.2ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 2 goblins, 38.2ms
# Speed: 0.8ms preprocess, 38.2ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 42.3ms
# Speed: 0.8ms preprocess, 42.3ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 2 goblins, 38.5ms
# Speed: 0.9ms preprocess, 38.5ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 4 goblins, 38.7ms
# Speed: 0.7ms preprocess, 38.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 39.4ms
# Speed: 0.9ms preprocess, 39.4ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 4 goblins, 38.9ms
# Speed: 0.8ms preprocess, 38.9ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 4 goblins, 40.2ms
# Speed: 0.8ms preprocess, 40.2ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 2 goblins, 38.1ms
# Speed: 0.8ms preprocess, 38.1ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 2 goblins, 37.9ms
# Speed: 0.8ms preprocess, 37.9ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 2 goblins, 39.6ms
# Speed: 0.9ms preprocess, 39.6ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 1 goblin, 36.6ms
# Speed: 0.8ms preprocess, 36.6ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 38.2ms
# Speed: 0.9ms preprocess, 38.2ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 37.7ms
# Speed: 0.9ms preprocess, 37.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 4 goblins, 36.8ms
# Speed: 0.8ms preprocess, 36.8ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 2 goblins, 39.5ms
# Speed: 1.2ms preprocess, 39.5ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 4 goblins, 39.2ms
# Speed: 0.8ms preprocess, 39.2ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 41.2ms
# Speed: 0.8ms preprocess, 41.2ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 4 goblins, 42.5ms
# Speed: 0.9ms preprocess, 42.5ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 2 goblins, 55.8ms
# Speed: 0.9ms preprocess, 55.8ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 2 goblins, 44.0ms
# Speed: 0.9ms preprocess, 44.0ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 4 goblins, 41.4ms
# Speed: 1.2ms preprocess, 41.4ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 4 goblins, 43.6ms
# Speed: 1.1ms preprocess, 43.6ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 4 goblins, 35.8ms
# Speed: 0.8ms preprocess, 35.8ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 35.9ms
# Speed: 0.9ms preprocess, 35.9ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 5 goblins, 36.2ms
# Speed: 0.8ms preprocess, 36.2ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 4 goblins, 36.5ms
# Speed: 1.1ms preprocess, 36.5ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 35.2ms
# Speed: 1.0ms preprocess, 35.2ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 2 goblins, 36.0ms
# Speed: 0.7ms preprocess, 36.0ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 4 goblins, 35.8ms
# Speed: 0.9ms preprocess, 35.8ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 7 goblins, 39.1ms
# Speed: 0.8ms preprocess, 39.1ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 38.5ms
# Speed: 0.8ms preprocess, 38.5ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 2 goblins, 43.5ms
# Speed: 0.7ms preprocess, 43.5ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 2 goblins, 43.9ms
# Speed: 0.7ms preprocess, 43.9ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 2 goblins, 55.7ms
# Speed: 1.0ms preprocess, 55.7ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 55.2ms
# Speed: 1.3ms preprocess, 55.2ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 2 goblins, 43.6ms
# Speed: 1.3ms preprocess, 43.6ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 1 goblin, 43.9ms
# Speed: 1.4ms preprocess, 43.9ms inference, 0.4ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 42.4ms
# Speed: 0.8ms preprocess, 42.4ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 2 goblins, 38.4ms
# Speed: 0.7ms preprocess, 38.4ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 38.7ms
# Speed: 0.8ms preprocess, 38.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
# 🎯 Attacking goblin at (476, 322)...
# ✅ Clicked on goblin.
#
# 0: 224x320 5 goblins, 48.6ms
# Speed: 1.0ms preprocess, 48.6ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 5 goblins, 42.8ms
# Speed: 0.8ms preprocess, 42.8ms inference, 0.8ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 6 goblins, 39.3ms
# Speed: 0.8ms preprocess, 39.3ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 6 goblins, 40.2ms
# Speed: 1.0ms preprocess, 40.2ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 5 goblins, 41.8ms
# Speed: 1.4ms preprocess, 41.8ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 5 goblins, 34.6ms
# Speed: 0.7ms preprocess, 34.6ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 5 goblins, 38.6ms
# Speed: 1.0ms preprocess, 38.6ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 4 goblins, 39.9ms
# Speed: 0.8ms preprocess, 39.9ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 2 goblins, 41.6ms
# Speed: 1.3ms preprocess, 41.6ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 2 goblins, 38.7ms
# Speed: 1.2ms preprocess, 38.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 36.8ms
# Speed: 0.8ms preprocess, 36.8ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 40.9ms
# Speed: 0.9ms preprocess, 40.9ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 7 goblins, 38.2ms
# Speed: 0.8ms preprocess, 38.2ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 5 goblins, 41.5ms
# Speed: 0.9ms preprocess, 41.5ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 4 goblins, 61.3ms
# Speed: 1.5ms preprocess, 61.3ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 4 goblins, 73.7ms
# Speed: 1.2ms preprocess, 73.7ms inference, 0.9ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 44.6ms
# Speed: 0.8ms preprocess, 44.6ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 4 goblins, 37.8ms
# Speed: 0.9ms preprocess, 37.8ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 37.5ms
# Speed: 0.9ms preprocess, 37.5ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 2 goblins, 38.3ms
# Speed: 0.8ms preprocess, 38.3ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 1 goblin, 38.6ms
# Speed: 0.8ms preprocess, 38.6ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 2 goblins, 35.8ms
# Speed: 1.1ms preprocess, 35.8ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 65.4ms
# Speed: 0.9ms preprocess, 65.4ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 46.9ms
# Speed: 1.0ms preprocess, 46.9ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 4 goblins, 44.9ms
# Speed: 1.0ms preprocess, 44.9ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 2 goblins, 43.4ms
# Speed: 1.2ms preprocess, 43.4ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 49.0ms
# Speed: 1.0ms preprocess, 49.0ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 4 goblins, 43.5ms
# Speed: 0.8ms preprocess, 43.5ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 42.1ms
# Speed: 1.2ms preprocess, 42.1ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 2 goblins, 39.7ms
# Speed: 1.0ms preprocess, 39.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 2 goblins, 42.4ms
# Speed: 0.8ms preprocess, 42.4ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 2 goblins, 35.3ms
# Speed: 0.8ms preprocess, 35.3ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 1 goblin, 37.4ms
# Speed: 0.8ms preprocess, 37.4ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 1 goblin, 38.0ms
# Speed: 0.8ms preprocess, 38.0ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 38.7ms
# Speed: 1.5ms preprocess, 38.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 2 goblins, 39.3ms
# Speed: 0.8ms preprocess, 39.3ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 2 goblins, 42.8ms
# Speed: 1.6ms preprocess, 42.8ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 1 goblin, 44.7ms
# Speed: 1.3ms preprocess, 44.7ms inference, 0.4ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 1 goblin, 41.6ms
# Speed: 0.8ms preprocess, 41.6ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 (no detections), 42.0ms
# Speed: 1.1ms preprocess, 42.0ms inference, 0.3ms postprocess per image at shape (1, 3, 224, 320)
# ⚠️ No goblins detected.
#
# 0: 224x320 1 goblin, 44.0ms
# Speed: 0.8ms preprocess, 44.0ms inference, 0.4ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 2 goblins, 40.1ms
# Speed: 1.1ms preprocess, 40.1ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 1 goblin, 40.9ms
# Speed: 0.8ms preprocess, 40.9ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 2 goblins, 39.4ms
# Speed: 0.8ms preprocess, 39.4ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 2 goblins, 45.7ms
# Speed: 0.9ms preprocess, 45.7ms inference, 1.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 2 goblins, 47.7ms
# Speed: 1.0ms preprocess, 47.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 4 goblins, 42.5ms
# Speed: 1.1ms preprocess, 42.5ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 2 goblins, 41.8ms
# Speed: 0.9ms preprocess, 41.8ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 2 goblins, 38.5ms
# Speed: 0.9ms preprocess, 38.5ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 1 goblin, 39.1ms
# Speed: 0.9ms preprocess, 39.1ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 1 goblin, 43.9ms
# Speed: 1.0ms preprocess, 43.9ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 1 goblin, 39.3ms
# Speed: 0.9ms preprocess, 39.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 2 goblins, 48.0ms
# Speed: 0.8ms preprocess, 48.0ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 2 goblins, 64.1ms
# Speed: 0.9ms preprocess, 64.1ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 2 goblins, 54.5ms
# Speed: 0.7ms preprocess, 54.5ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 44.7ms
# Speed: 1.0ms preprocess, 44.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 35.4ms
# Speed: 0.9ms preprocess, 35.4ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 2 goblins, 36.8ms
# Speed: 0.8ms preprocess, 36.8ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 2 goblins, 37.3ms
# Speed: 0.8ms preprocess, 37.3ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 2 goblins, 39.0ms
# Speed: 0.8ms preprocess, 39.0ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 35.8ms
# Speed: 0.9ms preprocess, 35.8ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 36.1ms
# Speed: 0.9ms preprocess, 36.1ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 35.3ms
# Speed: 0.7ms preprocess, 35.3ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 35.7ms
# Speed: 0.8ms preprocess, 35.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 2 goblins, 35.3ms
# Speed: 1.0ms preprocess, 35.3ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 35.6ms
# Speed: 0.7ms preprocess, 35.6ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 4 goblins, 51.5ms
# Speed: 0.8ms preprocess, 51.5ms inference, 0.9ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 2 goblins, 59.6ms
# Speed: 1.4ms preprocess, 59.6ms inference, 0.9ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 44.1ms
# Speed: 1.4ms preprocess, 44.1ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 40.9ms
# Speed: 1.2ms preprocess, 40.9ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 2 goblins, 40.1ms
# Speed: 1.0ms preprocess, 40.1ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 38.8ms
# Speed: 0.9ms preprocess, 38.8ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 5 goblins, 42.3ms
# Speed: 1.1ms preprocess, 42.3ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 4 goblins, 46.3ms
# Speed: 1.0ms preprocess, 46.3ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 2 goblins, 39.5ms
# Speed: 1.1ms preprocess, 39.5ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 1 goblin, 42.0ms
# Speed: 1.1ms preprocess, 42.0ms inference, 0.4ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 38.0ms
# Speed: 0.9ms preprocess, 38.0ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 (no detections), 36.9ms
# Speed: 0.9ms preprocess, 36.9ms inference, 0.3ms postprocess per image at shape (1, 3, 224, 320)
# ⚠️ No goblins detected.
#
# 0: 224x320 1 goblin, 38.7ms
# Speed: 0.8ms preprocess, 38.7ms inference, 0.4ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 (no detections), 37.2ms
# Speed: 0.9ms preprocess, 37.2ms inference, 0.3ms postprocess per image at shape (1, 3, 224, 320)
# ⚠️ No goblins detected.
#
# 0: 224x320 2 goblins, 39.0ms
# Speed: 0.6ms preprocess, 39.0ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 1 goblin, 37.5ms
# Speed: 0.8ms preprocess, 37.5ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 37.0ms
# Speed: 0.9ms preprocess, 37.0ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 1 goblin, 38.9ms
# Speed: 0.9ms preprocess, 38.9ms inference, 0.4ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 1 goblin, 37.3ms
# Speed: 1.0ms preprocess, 37.3ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 1 goblin, 35.8ms
# Speed: 0.8ms preprocess, 35.8ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 2 goblins, 36.5ms
# Speed: 0.8ms preprocess, 36.5ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 2 goblins, 39.3ms
# Speed: 1.0ms preprocess, 39.3ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 2 goblins, 75.1ms
# Speed: 4.9ms preprocess, 75.1ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 1 goblin, 43.7ms
# Speed: 1.0ms preprocess, 43.7ms inference, 0.4ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 (no detections), 57.5ms
# Speed: 2.3ms preprocess, 57.5ms inference, 0.3ms postprocess per image at shape (1, 3, 224, 320)
# ⚠️ No goblins detected.
#
# 0: 224x320 (no detections), 44.7ms
# Speed: 1.0ms preprocess, 44.7ms inference, 0.3ms postprocess per image at shape (1, 3, 224, 320)
# ⚠️ No goblins detected.
#
# 0: 224x320 2 goblins, 42.9ms
# Speed: 0.8ms preprocess, 42.9ms inference, 0.8ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 (no detections), 38.1ms
# Speed: 1.4ms preprocess, 38.1ms inference, 0.3ms postprocess per image at shape (1, 3, 224, 320)
# ⚠️ No goblins detected.
#
# 0: 224x320 1 goblin, 39.5ms
# Speed: 1.0ms preprocess, 39.5ms inference, 0.4ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 1 goblin, 39.7ms
# Speed: 1.1ms preprocess, 39.7ms inference, 0.4ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 1 goblin, 40.3ms
# Speed: 0.9ms preprocess, 40.3ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 1 goblin, 38.6ms
# Speed: 0.8ms preprocess, 38.6ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 1 goblin, 41.7ms
# Speed: 0.8ms preprocess, 41.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 2 goblins, 37.3ms
# Speed: 0.9ms preprocess, 37.3ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 38.5ms
# Speed: 1.1ms preprocess, 38.5ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 2 goblins, 36.7ms
# Speed: 0.8ms preprocess, 36.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 1 goblin, 37.9ms
# Speed: 0.8ms preprocess, 37.9ms inference, 0.4ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 1 goblin, 35.5ms
# Speed: 1.0ms preprocess, 35.5ms inference, 0.4ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 (no detections), 35.6ms
# Speed: 0.8ms preprocess, 35.6ms inference, 0.4ms postprocess per image at shape (1, 3, 224, 320)
# ⚠️ No goblins detected.
#
# 0: 224x320 2 goblins, 39.8ms
# Speed: 0.8ms preprocess, 39.8ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 2 goblins, 37.5ms
# Speed: 0.9ms preprocess, 37.5ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 2 goblins, 38.0ms
# Speed: 0.8ms preprocess, 38.0ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 36.6ms
# Speed: 0.8ms preprocess, 36.6ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 (no detections), 48.1ms
# Speed: 0.7ms preprocess, 48.1ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 320)
# ⚠️ No goblins detected.
#
# 0: 224x320 2 goblins, 45.6ms
# Speed: 1.1ms preprocess, 45.6ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 2 goblins, 42.4ms
# Speed: 1.0ms preprocess, 42.4ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 (no detections), 39.4ms
# Speed: 0.9ms preprocess, 39.4ms inference, 0.3ms postprocess per image at shape (1, 3, 224, 320)
# ⚠️ No goblins detected.
#
# 0: 224x320 1 goblin, 35.0ms
# Speed: 0.7ms preprocess, 35.0ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 2 goblins, 37.9ms
# Speed: 0.7ms preprocess, 37.9ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 2 goblins, 35.8ms
# Speed: 0.8ms preprocess, 35.8ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 (no detections), 37.3ms
# Speed: 1.1ms preprocess, 37.3ms inference, 0.3ms postprocess per image at shape (1, 3, 224, 320)
# ⚠️ No goblins detected.
#
# 0: 224x320 (no detections), 35.3ms
# Speed: 0.8ms preprocess, 35.3ms inference, 0.3ms postprocess per image at shape (1, 3, 224, 320)
# ⚠️ No goblins detected.
#
# 0: 224x320 1 goblin, 36.6ms
# Speed: 0.7ms preprocess, 36.6ms inference, 0.4ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 (no detections), 48.0ms
# Speed: 0.9ms preprocess, 48.0ms inference, 0.3ms postprocess per image at shape (1, 3, 224, 320)
# ⚠️ No goblins detected.
#
# 0: 224x320 2 goblins, 43.5ms
# Speed: 1.0ms preprocess, 43.5ms inference, 0.9ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 5 goblins, 40.6ms
# Speed: 0.7ms preprocess, 40.6ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 4 goblins, 38.9ms
# Speed: 0.9ms preprocess, 38.9ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 5 goblins, 37.2ms
# Speed: 0.8ms preprocess, 37.2ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 5 goblins, 36.6ms
# Speed: 0.8ms preprocess, 36.6ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 49.2ms
# Speed: 0.9ms preprocess, 49.2ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 46.4ms
# Speed: 1.0ms preprocess, 46.4ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 1 goblin, 38.9ms
# Speed: 1.0ms preprocess, 38.9ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 2 goblins, 41.2ms
# Speed: 0.7ms preprocess, 41.2ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 1 goblin, 37.1ms
# Speed: 0.9ms preprocess, 37.1ms inference, 0.4ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 2 goblins, 64.0ms
# Speed: 0.9ms preprocess, 64.0ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 2 goblins, 43.4ms
# Speed: 0.9ms preprocess, 43.4ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 1 goblin, 47.2ms
# Speed: 0.9ms preprocess, 47.2ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 1 goblin, 49.2ms
# Speed: 0.9ms preprocess, 49.2ms inference, 0.4ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 2 goblins, 39.0ms
# Speed: 2.1ms preprocess, 39.0ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 2 goblins, 38.7ms
# Speed: 0.8ms preprocess, 38.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 2 goblins, 36.6ms
# Speed: 0.8ms preprocess, 36.6ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 1 goblin, 35.3ms
# Speed: 0.9ms preprocess, 35.3ms inference, 0.4ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 1 goblin, 40.9ms
# Speed: 0.9ms preprocess, 40.9ms inference, 0.4ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 (no detections), 36.2ms
# Speed: 0.8ms preprocess, 36.2ms inference, 0.2ms postprocess per image at shape (1, 3, 224, 320)
# ⚠️ No goblins detected.
#
# 0: 224x320 3 goblins, 35.5ms
# Speed: 0.7ms preprocess, 35.5ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 1 goblin, 39.6ms
# Speed: 0.8ms preprocess, 39.6ms inference, 0.4ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 1 goblin, 37.4ms
# Speed: 1.0ms preprocess, 37.4ms inference, 0.4ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 1 goblin, 40.1ms
# Speed: 0.8ms preprocess, 40.1ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 2 goblins, 43.1ms
# Speed: 2.1ms preprocess, 43.1ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 36.8ms
# Speed: 0.8ms preprocess, 36.8ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 1 goblin, 39.1ms
# Speed: 1.3ms preprocess, 39.1ms inference, 0.8ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 (no detections), 39.5ms
# Speed: 0.8ms preprocess, 39.5ms inference, 0.3ms postprocess per image at shape (1, 3, 224, 320)
# ⚠️ No goblins detected.
#
# 0: 224x320 2 goblins, 38.5ms
# Speed: 0.8ms preprocess, 38.5ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 1 goblin, 35.6ms
# Speed: 0.7ms preprocess, 35.6ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 (no detections), 36.0ms
# Speed: 1.0ms preprocess, 36.0ms inference, 0.4ms postprocess per image at shape (1, 3, 224, 320)
# ⚠️ No goblins detected.
#
# 0: 224x320 (no detections), 55.5ms
# Speed: 0.8ms preprocess, 55.5ms inference, 0.4ms postprocess per image at shape (1, 3, 224, 320)
# ⚠️ No goblins detected.
#
# 0: 224x320 (no detections), 46.4ms
# Speed: 1.0ms preprocess, 46.4ms inference, 0.3ms postprocess per image at shape (1, 3, 224, 320)
# ⚠️ No goblins detected.
#
# 0: 224x320 1 goblin, 48.1ms
# Speed: 0.9ms preprocess, 48.1ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 2 goblins, 42.3ms
# Speed: 0.8ms preprocess, 42.3ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 5 goblins, 52.3ms
# Speed: 1.2ms preprocess, 52.3ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 7 goblins, 42.2ms
# Speed: 1.7ms preprocess, 42.2ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 39.8ms
# Speed: 1.0ms preprocess, 39.8ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 2 goblins, 40.5ms
# Speed: 0.9ms preprocess, 40.5ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 1 goblin, 37.3ms
# Speed: 1.7ms preprocess, 37.3ms inference, 0.4ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 2 goblins, 53.6ms
# Speed: 0.9ms preprocess, 53.6ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 1 goblin, 45.0ms
# Speed: 1.1ms preprocess, 45.0ms inference, 0.4ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 4 goblins, 40.5ms
# Speed: 0.8ms preprocess, 40.5ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 4 goblins, 40.7ms
# Speed: 1.2ms preprocess, 40.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 1 goblin, 58.4ms
# Speed: 1.5ms preprocess, 58.4ms inference, 0.4ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 (no detections), 40.0ms
# Speed: 1.2ms preprocess, 40.0ms inference, 0.3ms postprocess per image at shape (1, 3, 224, 320)
# ⚠️ No goblins detected.
#
# 0: 224x320 1 goblin, 38.4ms
# Speed: 0.8ms preprocess, 38.4ms inference, 0.4ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 2 goblins, 38.7ms
# Speed: 0.9ms preprocess, 38.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 2 goblins, 35.7ms
# Speed: 0.8ms preprocess, 35.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 39.1ms
# Speed: 0.9ms preprocess, 39.1ms inference, 0.8ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 1 goblin, 43.9ms
# Speed: 0.8ms preprocess, 43.9ms inference, 2.0ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 1 goblin, 49.0ms
# Speed: 1.0ms preprocess, 49.0ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 (no detections), 45.0ms
# Speed: 1.1ms preprocess, 45.0ms inference, 0.3ms postprocess per image at shape (1, 3, 224, 320)
# ⚠️ No goblins detected.
#
# 0: 224x320 1 goblin, 43.1ms
# Speed: 0.8ms preprocess, 43.1ms inference, 0.4ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 (no detections), 38.5ms
# Speed: 0.7ms preprocess, 38.5ms inference, 0.3ms postprocess per image at shape (1, 3, 224, 320)
# ⚠️ No goblins detected.
#
# 0: 224x320 1 goblin, 38.3ms
# Speed: 0.8ms preprocess, 38.3ms inference, 0.4ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 1 goblin, 38.3ms
# Speed: 0.9ms preprocess, 38.3ms inference, 0.4ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 1 goblin, 39.8ms
# Speed: 0.8ms preprocess, 39.8ms inference, 0.4ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 36.7ms
# Speed: 0.8ms preprocess, 36.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 2 goblins, 38.2ms
# Speed: 0.9ms preprocess, 38.2ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 2 goblins, 39.3ms
# Speed: 0.9ms preprocess, 39.3ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 2 goblins, 46.5ms
# Speed: 1.3ms preprocess, 46.5ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 2 goblins, 38.8ms
# Speed: 1.0ms preprocess, 38.8ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 1 goblin, 40.2ms
# Speed: 1.4ms preprocess, 40.2ms inference, 0.4ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 2 goblins, 35.3ms
# Speed: 0.8ms preprocess, 35.3ms inference, 0.9ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 2 goblins, 36.6ms
# Speed: 0.8ms preprocess, 36.6ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 1 goblin, 36.1ms
# Speed: 0.9ms preprocess, 36.1ms inference, 0.4ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 (no detections), 34.6ms
# Speed: 0.8ms preprocess, 34.6ms inference, 0.3ms postprocess per image at shape (1, 3, 224, 320)
# ⚠️ No goblins detected.
#
# 0: 224x320 (no detections), 35.3ms
# Speed: 0.8ms preprocess, 35.3ms inference, 0.3ms postprocess per image at shape (1, 3, 224, 320)
# ⚠️ No goblins detected.
#
# 0: 224x320 (no detections), 41.9ms
# Speed: 0.7ms preprocess, 41.9ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 320)
# ⚠️ No goblins detected.
#
# 0: 224x320 1 goblin, 48.5ms
# Speed: 0.9ms preprocess, 48.5ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 (no detections), 39.7ms
# Speed: 1.0ms preprocess, 39.7ms inference, 0.3ms postprocess per image at shape (1, 3, 224, 320)
# ⚠️ No goblins detected.
#
# 0: 224x320 1 goblin, 39.7ms
# Speed: 0.9ms preprocess, 39.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 (no detections), 53.7ms
# Speed: 1.0ms preprocess, 53.7ms inference, 0.3ms postprocess per image at shape (1, 3, 224, 320)
# ⚠️ No goblins detected.
#
# 0: 224x320 (no detections), 36.5ms
# Speed: 0.7ms preprocess, 36.5ms inference, 0.3ms postprocess per image at shape (1, 3, 224, 320)
# ⚠️ No goblins detected.
#
# 0: 224x320 (no detections), 36.0ms
# Speed: 0.7ms preprocess, 36.0ms inference, 0.3ms postprocess per image at shape (1, 3, 224, 320)
# ⚠️ No goblins detected.
#
# 0: 224x320 (no detections), 37.2ms
# Speed: 0.8ms preprocess, 37.2ms inference, 0.3ms postprocess per image at shape (1, 3, 224, 320)
# ⚠️ No goblins detected.
#
# 0: 224x320 1 goblin, 36.7ms
# Speed: 0.8ms preprocess, 36.7ms inference, 0.4ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 (no detections), 35.9ms
# Speed: 0.8ms preprocess, 35.9ms inference, 0.3ms postprocess per image at shape (1, 3, 224, 320)
# ⚠️ No goblins detected.
#
# 0: 224x320 (no detections), 35.6ms
# Speed: 0.7ms preprocess, 35.6ms inference, 0.3ms postprocess per image at shape (1, 3, 224, 320)
# ⚠️ No goblins detected.
#
# 0: 224x320 (no detections), 36.3ms
# Speed: 0.9ms preprocess, 36.3ms inference, 0.3ms postprocess per image at shape (1, 3, 224, 320)
# ⚠️ No goblins detected.
#
# 0: 224x320 2 goblins, 37.3ms
# Speed: 0.8ms preprocess, 37.3ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 (no detections), 37.1ms
# Speed: 0.8ms preprocess, 37.1ms inference, 0.3ms postprocess per image at shape (1, 3, 224, 320)
# ⚠️ No goblins detected.
#
# 0: 224x320 (no detections), 37.6ms
# Speed: 0.8ms preprocess, 37.6ms inference, 0.3ms postprocess per image at shape (1, 3, 224, 320)
# ⚠️ No goblins detected.
#
# 0: 224x320 1 goblin, 39.7ms
# Speed: 0.7ms preprocess, 39.7ms inference, 0.4ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 1 goblin, 37.1ms
# Speed: 1.4ms preprocess, 37.1ms inference, 0.4ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 (no detections), 36.7ms
# Speed: 0.8ms preprocess, 36.7ms inference, 0.3ms postprocess per image at shape (1, 3, 224, 320)
# ⚠️ No goblins detected.
#
# 0: 224x320 (no detections), 39.5ms
# Speed: 0.8ms preprocess, 39.5ms inference, 0.3ms postprocess per image at shape (1, 3, 224, 320)
# ⚠️ No goblins detected.
#
# 0: 224x320 (no detections), 41.7ms
# Speed: 0.9ms preprocess, 41.7ms inference, 0.3ms postprocess per image at shape (1, 3, 224, 320)
# ⚠️ No goblins detected.
#
# 0: 224x320 1 goblin, 43.5ms
# Speed: 0.8ms preprocess, 43.5ms inference, 0.4ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 1 goblin, 36.3ms
# Speed: 0.7ms preprocess, 36.3ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 1 goblin, 55.7ms
# Speed: 1.1ms preprocess, 55.7ms inference, 0.4ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 1 goblin, 44.5ms
# Speed: 0.9ms preprocess, 44.5ms inference, 0.4ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 39.9ms
# Speed: 1.0ms preprocess, 39.9ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# ...
#
# 0: 224x320 3 goblins, 41.1ms
# Speed: 0.9ms preprocess, 41.1ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 35.7ms
# Speed: 0.8ms preprocess, 35.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 35.3ms
# Speed: 0.8ms preprocess, 35.3ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 320)
# 🎯 Attacking goblin at (353, 331)...
# ✅ Clicked on goblin.
#
# 0: 224x320 3 goblins, 47.3ms
# Speed: 1.3ms preprocess, 47.3ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 39.3ms
# Speed: 0.8ms preprocess, 39.3ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 37.8ms
# Speed: 0.8ms preprocess, 37.8ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 43.2ms
# Speed: 1.0ms preprocess, 43.2ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 2 goblins, 43.8ms
# Speed: 0.8ms preprocess, 43.8ms inference, 0.8ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 47.6ms
# Speed: 0.9ms preprocess, 47.6ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 2 goblins, 128.9ms
# Speed: 1.0ms preprocess, 128.9ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 68.1ms
# Speed: 1.0ms preprocess, 68.1ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 4 goblins, 44.1ms
# Speed: 1.2ms preprocess, 44.1ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 4 goblins, 49.8ms
# Speed: 1.4ms preprocess, 49.8ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 4 goblins, 43.9ms
# Speed: 0.9ms preprocess, 43.9ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 4 goblins, 40.0ms
# Speed: 0.9ms preprocess, 40.0ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 4 goblins, 52.4ms
# Speed: 1.2ms preprocess, 52.4ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 58.1ms
# Speed: 1.1ms preprocess, 58.1ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 76.6ms
# Speed: 1.0ms preprocess, 76.6ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 4 goblins, 45.9ms
# Speed: 1.2ms preprocess, 45.9ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 57.2ms
# Speed: 1.3ms preprocess, 57.2ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 58.0ms
# Speed: 1.0ms preprocess, 58.0ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 40.6ms
# Speed: 1.1ms preprocess, 40.6ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 41.1ms
# Speed: 1.0ms preprocess, 41.1ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 40.2ms
# Speed: 0.9ms preprocess, 40.2ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 37.2ms
# Speed: 1.0ms preprocess, 37.2ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 5 goblins, 61.4ms
# Speed: 1.0ms preprocess, 61.4ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 4 goblins, 50.0ms
# Speed: 0.9ms preprocess, 50.0ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 4 goblins, 44.9ms
# Speed: 1.0ms preprocess, 44.9ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 4 goblins, 41.7ms
# Speed: 1.1ms preprocess, 41.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 39.6ms
# Speed: 1.1ms preprocess, 39.6ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 36.2ms
# Speed: 1.0ms preprocess, 36.2ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 54.1ms
# Speed: 0.9ms preprocess, 54.1ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 53.2ms
# Speed: 1.1ms preprocess, 53.2ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 43.3ms
# Speed: 1.0ms preprocess, 43.3ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 43.1ms
# Speed: 0.9ms preprocess, 43.1ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 55.7ms
# Speed: 1.3ms preprocess, 55.7ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 4 goblins, 48.2ms
# Speed: 0.8ms preprocess, 48.2ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 48.8ms
# Speed: 0.9ms preprocess, 48.8ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 39.0ms
# Speed: 0.9ms preprocess, 39.0ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 4 goblins, 66.1ms
# Speed: 1.1ms preprocess, 66.1ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 49.3ms
# Speed: 1.3ms preprocess, 49.3ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 39.1ms
# Speed: 1.0ms preprocess, 39.1ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 37.4ms
# Speed: 0.7ms preprocess, 37.4ms inference, 0.5ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 4 goblins, 33.5ms
# Speed: 0.8ms preprocess, 33.5ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 48.2ms
# Speed: 0.9ms preprocess, 48.2ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 2 goblins, 65.9ms
# Speed: 1.0ms preprocess, 65.9ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 2 goblins, 45.7ms
# Speed: 0.9ms preprocess, 45.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 50.8ms
# Speed: 1.6ms preprocess, 50.8ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 4 goblins, 46.5ms
# Speed: 1.2ms preprocess, 46.5ms inference, 0.9ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 4 goblins, 48.7ms
# Speed: 1.0ms preprocess, 48.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 40.4ms
# Speed: 0.9ms preprocess, 40.4ms inference, 0.9ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 39.1ms
# Speed: 0.9ms preprocess, 39.1ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 46.9ms
# Speed: 0.9ms preprocess, 46.9ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 4 goblins, 41.4ms
# Speed: 1.0ms preprocess, 41.4ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 4 goblins, 87.5ms
# Speed: 0.8ms preprocess, 87.5ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 4 goblins, 38.7ms
# Speed: 1.1ms preprocess, 38.7ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 4 goblins, 43.4ms
# Speed: 1.0ms preprocess, 43.4ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 4 goblins, 45.5ms
# Speed: 0.9ms preprocess, 45.5ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 4 goblins, 45.4ms
# Speed: 0.9ms preprocess, 45.4ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 4 goblins, 49.3ms
# Speed: 1.0ms preprocess, 49.3ms inference, 0.8ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 4 goblins, 38.6ms
# Speed: 1.2ms preprocess, 38.6ms inference, 0.8ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 4 goblins, 37.5ms
# Speed: 1.0ms preprocess, 37.5ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 4 goblins, 56.0ms
# Speed: 1.0ms preprocess, 56.0ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 41.1ms
# Speed: 1.1ms preprocess, 41.1ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 4 goblins, 38.7ms
# Speed: 0.9ms preprocess, 38.7ms inference, 0.9ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 4 goblins, 36.6ms
# Speed: 0.9ms preprocess, 36.6ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 2 goblins, 33.8ms
# Speed: 0.8ms preprocess, 33.8ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 2 goblins, 40.7ms
# Speed: 0.7ms preprocess, 40.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 2 goblins, 100.7ms
# Speed: 1.0ms preprocess, 100.7ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 2 goblins, 59.9ms
# Speed: 0.8ms preprocess, 59.9ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 2 goblins, 40.7ms
# Speed: 1.2ms preprocess, 40.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 2 goblins, 41.2ms
# Speed: 0.9ms preprocess, 41.2ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 59.1ms
# Speed: 1.2ms preprocess, 59.1ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 80.2ms
# Speed: 1.2ms preprocess, 80.2ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 49.1ms
# Speed: 0.9ms preprocess, 49.1ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 43.6ms
# Speed: 1.1ms preprocess, 43.6ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 41.9ms
# Speed: 0.8ms preprocess, 41.9ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 56.6ms
# Speed: 1.2ms preprocess, 56.6ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 52.1ms
# Speed: 1.6ms preprocess, 52.1ms inference, 0.9ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 39.4ms
# Speed: 1.5ms preprocess, 39.4ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 45.6ms
# Speed: 0.9ms preprocess, 45.6ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 4 goblins, 49.1ms
# Speed: 1.2ms preprocess, 49.1ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 4 goblins, 44.1ms
# Speed: 1.0ms preprocess, 44.1ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 4 goblins, 42.5ms
# Speed: 1.1ms preprocess, 42.5ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 4 goblins, 56.5ms
# Speed: 0.8ms preprocess, 56.5ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 4 goblins, 44.7ms
# Speed: 1.5ms preprocess, 44.7ms inference, 0.8ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 4 goblins, 44.2ms
# Speed: 0.9ms preprocess, 44.2ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 4 goblins, 47.5ms
# Speed: 0.9ms preprocess, 47.5ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 44.8ms
# Speed: 1.2ms preprocess, 44.8ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 1 Goblin, 4 goblins, 45.4ms
# Speed: 0.9ms preprocess, 45.4ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 1 Goblin, 4 goblins, 40.8ms
# Speed: 1.0ms preprocess, 40.8ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 1 Goblin, 4 goblins, 57.9ms
# Speed: 0.9ms preprocess, 57.9ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 4 goblins, 45.9ms
# Speed: 1.0ms preprocess, 45.9ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 42.5ms
# Speed: 0.8ms preprocess, 42.5ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 4 goblins, 40.8ms
# Speed: 2.0ms preprocess, 40.8ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 4 goblins, 36.7ms
# Speed: 1.0ms preprocess, 36.7ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 1 Goblin, 4 goblins, 48.4ms
# Speed: 0.8ms preprocess, 48.4ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 1 Goblin, 4 goblins, 56.2ms
# Speed: 1.2ms preprocess, 56.2ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 1 Goblin, 4 goblins, 51.2ms
# Speed: 1.0ms preprocess, 51.2ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 4 goblins, 76.4ms
# Speed: 0.8ms preprocess, 76.4ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 4 goblins, 49.4ms
# Speed: 1.2ms preprocess, 49.4ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 1 Goblin, 5 goblins, 50.7ms
# Speed: 1.1ms preprocess, 50.7ms inference, 0.8ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 1 Goblin, 5 goblins, 45.5ms
# Speed: 1.2ms preprocess, 45.5ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 5 goblins, 44.5ms
# Speed: 1.1ms preprocess, 44.5ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 4 goblins, 39.6ms
# Speed: 0.8ms preprocess, 39.6ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 4 goblins, 39.1ms
# Speed: 0.9ms preprocess, 39.1ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 6 goblins, 72.0ms
# Speed: 0.9ms preprocess, 72.0ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 6 goblins, 42.7ms
# Speed: 1.1ms preprocess, 42.7ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 1 Goblin, 5 goblins, 41.8ms
# Speed: 0.8ms preprocess, 41.8ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 5 goblins, 41.2ms
# Speed: 0.9ms preprocess, 41.2ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 4 goblins, 43.2ms
# Speed: 0.8ms preprocess, 43.2ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 1 Goblin, 4 goblins, 38.9ms
# Speed: 1.0ms preprocess, 38.9ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 1 Goblin, 3 goblins, 65.8ms
# Speed: 1.1ms preprocess, 65.8ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 1 Goblin, 4 goblins, 77.5ms
# Speed: 1.0ms preprocess, 77.5ms inference, 0.8ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 1 Goblin, 5 goblins, 56.5ms
# Speed: 0.9ms preprocess, 56.5ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 1 Goblin, 5 goblins, 50.2ms
# Speed: 0.9ms preprocess, 50.2ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 1 Goblin, 5 goblins, 42.2ms
# Speed: 0.9ms preprocess, 42.2ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 1 Goblin, 4 goblins, 39.6ms
# Speed: 1.1ms preprocess, 39.6ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 1 Goblin, 5 goblins, 53.5ms
# Speed: 0.9ms preprocess, 53.5ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 4 goblins, 50.5ms
# Speed: 0.9ms preprocess, 50.5ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 4 goblins, 41.4ms
# Speed: 1.0ms preprocess, 41.4ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 50.6ms
# Speed: 1.3ms preprocess, 50.6ms inference, 0.6ms postprocess per image at shape (1, 3, 224, 320)
#
# 0: 224x320 3 goblins, 47.0ms
# Speed: 1.1ms preprocess, 47.0ms inference, 0.7ms postprocess per image at shape (1, 3, 224, 320)
# ❌ Stopping bot & tracking.
# ✅ Bot & tracking loop exited safely.

# %% [markdown]
# # 👾 Happy Botting! 🧌
#
# For any issues check read.me file
